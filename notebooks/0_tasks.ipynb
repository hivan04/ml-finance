# %% [markdown]
# ### Overview
# | Chapter / Phase                                   | Main Objective                                                | Key Tasks                                                                                                                                                                                             | Outputs You Need                                                                                               |
# | ------------------------------------------------- | ------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | -------------------------------------------------------------------------------------------------------------- |
# | **1. Introduction & Motivation**                  | Understand the economic logic behind the project              | Explain why dividend changes matter, why earnings surprises may predict dividend decisions, and why post-dividend-change drift may exist                                                              | Clear motivation section in report; explanation of earnings-to-dividend information lag and clientele rotation |
# | **1.1 Earnings & Dividend Calendar**              | Correctly understand event timing                             | Identify earnings announcement date, dividend declaration date, ex-dividend date, record date, and payment date; distinguish informative vs mechanical dates                                          | Correct event timeline; confirmation that the model predicts after earnings but before dividend declaration    |
# | **2. Research Hypotheses**                        | Formally define what you are testing                          | Test H1–H6: post-dividend drift, earnings-dividend link, conditional drift, asymmetric drift, earnings conditioning, and ML vs linear model                                                           | Hypotheses section in report; evidence for or against each hypothesis                                          |
# | **3. Data Requirements**                          | Gather and define required datasets                           | Collect dividend history, earnings announcements, daily prices, fundamentals, market/macro data, and sector classifications                                                                           | Raw datasets; documented data sources; defined investment universe                                             |
# | **3.2 Universe Definition**                       | Define tradable stock universe                                | Use S&P 1500 or comparable broad US universe; handle survivorship bias, liquidity filters, index changes, entry/exit of stocks                                                                        | Universe description; sample period, ideally 2005–2024                                                         |
# | **3.3 Data Integrity**                            | Avoid data errors and look-ahead bias                         | Use declaration dates, not ex-dates; lag fundamentals; adjust for splits/dividends; document missing data; check delistings after dividend cuts                                                       | Data integrity checklist; missing value report; survivorship-bias discussion                                   |
# | **4. Phase 1 — Data Preparation & EDA**           | Build clean merged research dataset                           | Ingest, clean, merge, transform, and explore all datasets                                                                                                                                             | Clean panel dataset saved as `.parquet`; EDA charts and tables                                                 |
# | **Task 1.1 Data Ingestion & Cleaning**            | Prepare raw data for modelling                                | Harmonise identifiers and dates; merge datasets; handle missing values; apply expanding-window winsorisation; transform heavy-tailed variables; cross-sectional z-scores                              | Clean merged research panel; imputation logic; transformed features                                            |
# | **Task 1.2 Dividend Event Classification**        | Label dividend events                                         | Classify each event as increase, decrease, unchanged, initiation, or special dividend; compute percentage DPS change; exclude special dividends from core change calculation                          | Dividend event table; event labels; DPS percentage change variable                                             |
# | **Task 1.3 Feature Engineering**                  | Build predictive features                                     | Create earnings surprise, payout, leverage, dividend history, market/sentiment, sector, and buyback/total payout features                                                                             | Feature matrix at each earnings announcement date                                                              |
# | **Task 1.4 Exploratory Analysis**                 | Understand dividend-event patterns                            | Produce summary stats by year and sector; dividend change histograms; earnings surprise vs dividend action cross-tab; feature correlation matrix; cut frequency vs VIX/yield curve                    | EDA section in report with charts and interpretation                                                           |
# | **5. Phase 2 — Event Study**                      | Prove whether tradeable post-dividend-change drift exists     | Compute CARs after dividend declarations; compare increases, decreases, initiations, unchanged dividends; test asymmetry and conditional effects                                                      | Event-study results, CAR tables, CAR path plots                                                                |
# | **Task 2.1 CAR Computation**                      | Measure abnormal returns after dividend announcements         | Compute raw, market-adjusted, and sector-adjusted CARs for windows: 1, 2, 3, 5, 10, 21, 42, 63, 126 trading days                                                                                      | CAR dataset by event and horizon                                                                               |
# | **Task 2.2 Aggregate CAR Analysis**               | Compare average drift by dividend event type                  | Compute mean, median, standard error, t-statistic, and event count for increases, decreases, initiations, and unchanged dividends                                                                     | Main CAR table; average CAR path chart with confidence bands                                                   |
# | **Task 2.3 Asymmetry Analysis**                   | Test whether cuts drift more than increases                   | Compare negative drift after cuts with positive drift after increases using Welch’s t-test or bootstrap test                                                                                          | H4 test result; interpretation of asymmetry                                                                    |
# | **Task 2.4 Conditional Drift Analysis**           | Identify where drift is strongest                             | Slice CARs by dividend change size, sector, VIX regime, rate cycle, earnings surprise interaction, and market cap                                                                                     | Conditional CAR plots and subgroup comparison tables                                                           |
# | **Task 2.5 Statistical Rigour**                   | Make event study credible                                     | Apply multiple-testing correction; bootstrap confidence intervals; discuss clustering and market-wide confounds                                                                                       | Robustness/statistical validity section                                                                        |
# | **6. Phase 3 — Dividend Change Prediction Model** | Predict next dividend action after earnings announcement      | Build ML model predicting increase, unchanged, or decrease at the next dividend declaration                                                                                                           | Trained models, predictions, validation metrics                                                                |
# | **6.1 Target Variable**                           | Define prediction target correctly                            | Label next dividend action after each earnings announcement: +1 increase, 0 unchanged, −1 decrease/omission; ensure declaration date is after earnings date                                           | Target variable table; timing validation check                                                                 |
# | **Task 3.1 Baseline Model**                       | Establish simple benchmark                                    | Implement ridge regression or logistic regression with L2 penalty; report IC and confusion matrix                                                                                                     | Baseline model results                                                                                         |
# | **Task 3.2 Primary Model**                        | Build main ML model                                           | Implement LightGBM, XGBoost, or CatBoost; choose either three-class classification or two binary models for increase/decrease                                                                         | Main model results; feature importance; predicted scores                                                       |
# | **Task 3.3 Advanced Model**                       | Add distinction-level extension                               | Choose one or more: two-stage model, FT-Transformer, TabNet, or NLP features from earnings call transcripts                                                                                           | Advanced model or extension section                                                                            |
# | **6.3 Validation Framework**                      | Validate model without leakage                                | Use mandatory walk-forward validation with at least 5 folds and 5-year training windows; report IC, AUC, confusion matrix, precision/recall, SHAP, IC stability                                       | Walk-forward validation results                                                                                |
# | **6.4 Model Diagnostics**                         | Explain and assess model behaviour                            | Produce SHAP summary plot, partial dependence plots, error analysis by sector/regime, calibration plot                                                                                                | Model diagnostics section                                                                                      |
# | **7. Phase 4 — Trading Strategy Construction**    | Convert predictions into a dollar-neutral long-short strategy | Use model scores to form long and short portfolios; test weighting schemes and holding periods                                                                                                        | Backtest-ready strategy signals and portfolio weights                                                          |
# | **Task 4.1 Signal Construction**                  | Define long/short signals                                     | Long high probability of dividend increase and low probability of cut; short high probability of cut; use rule-based thresholds such as top/bottom quintiles                                          | Signal-generation rules; model score thresholds                                                                |
# | **Task 4.2 Portfolio Construction**               | Build dollar-neutral portfolio                                | Enter next trading day after earnings announcement; compare equal-weight vs score-weighted portfolios; test 5, 10, 21, 42, 63-day holding periods; maintain dollar neutrality                         | Portfolio weights; holding-period comparison                                                                   |
# | **Task 4.3 Rebalancing Mechanics**                | Handle overlapping event-driven positions                     | Define what happens if new signal arrives for an already-held stock; aggregate overlapping cohorts; maintain dollar neutrality                                                                        | Rebalancing logic in `strategy.py`                                                                             |
# | **7.2 Transaction Cost Model**                    | Make backtest realistic                                       | Include spread/market impact, short borrow costs, slippage, and zero commission assumption; perform breakeven cost analysis                                                                           | Net-of-cost returns; breakeven transaction cost table                                                          |
# | **7.3 Risk Management**                           | Control portfolio risk                                        | Apply 5% max single-stock position limit; 30% max sector exposure per leg; describe drawdown control mechanism                                                                                        | Risk-rule documentation and checks                                                                             |
# | **8. Phase 5 — Performance Evaluation**           | Evaluate strategy rigorously                                  | Calculate full performance metrics, attribution, robustness, and regime performance                                                                                                                   | Final performance tables and charts                                                                            |
# | **8.1 Performance Metrics**                       | Report strategy performance                                   | CAGR, volatility, Sharpe, max drawdown, Calmar, turnover, hit rate, profit factor, long-leg CAGR, short-leg CAGR, strategy-level IC                                                                   | Strategy performance table                                                                                     |
# | **Task 5.1 Factor Regression**                    | Test whether alpha survives known factors                     | Regress daily strategy returns on Fama-French 5 factors plus momentum; report alpha, t-stat, factor loadings, adjusted R²                                                                             | Factor regression table                                                                                        |
# | **Task 5.2 Regime Analysis**                      | Check stability across market environments                    | Split performance into pre-2008, 2008–09, 2010–19, 2020, 2021–22, 2023–24                                                                                                                             | Regime performance table                                                                                       |
# | **Task 5.3 Robustness Checks**                    | Prove result is not fragile                                   | Exclude Utilities and REITs; compare ML to simple rule-based strategy; holding-period/threshold heatmap; final 2-year true out-of-sample test                                                         | Robustness section with tables/plots                                                                           |
# | **9. Technical Specifications**                   | Build reproducible Python codebase                            | Organise code into modular files: `config.py`, `data_loader.py`, `feature_engineering.py`, `target_engineering.py`, `event_study.py`, `model.py`, `strategy.py`, `backtest.py`, `utils.py`, `main.py` | Complete runnable Python project                                                                               |
# | **9.2 Coding Standards**                          | Meet implementation requirements                              | Use Python only; pandas/numpy; no unnecessary loops on dates; fixed random seeds; save outputs as `.parquet`; use functions with type hints                                                           | Clean, reproducible, modular code                                                                              |
# | **9.3 Anti-Lookahead Checklist**                  | Avoid major penalties                                         | Check feature timing, winsorisation, standardisation, targets, hyperparameter tuning, cross-sectional ranks, and trade execution timing                                                               | Final anti-lookahead validation checklist                                                                      |
# | **10. Deliverables**                              | Submit final report and code                                  | Write max 20-page report excluding appendices; submit complete codebase, README, and requirements/environment file                                                                                    | Final report, code submission, README, dependencies                                                            |
# | **11. Marking Criteria**                          | Prioritise marks efficiently                                  | Data/feature engineering 15%, event study 15%, model 20%, strategy/backtest 25%, report 15%, code 10%                                                                                                 | Use marking weights to prioritise time                                                                         |

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
