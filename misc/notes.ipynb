# %% [markdown]
# # Data Checklist

# %% [markdown]
# An important caveat: dividends are no longer the whole payout story. Since the early
# 2000s, share repurchases (buybacks) have increasingly replaced dividends as the
# dominant channel for returning cash to shareholders (Grullon & Michaely 2002b, Brav et
# al. 2005). A company that holds its dividend flat while substantially increasing its buyback
# programme is not necessarily signalling stagnation — it may simply prefer the flexibility
# and tax efficiency of repurchases. This means that a model focused exclusively on
# dividend changes will miss an important dimension of payout policy. You should be aware
# of this limitation throughout the project. In the feature engineering phase (Task 1.3), you
# will construct buyback-related features to help your model distinguish between genuine
# dividend stagnation and substitution. In the discussion section of your report, you should
# assess how much of your signal, if any, is contaminated by this substitution effect.

# %% [markdown]
# ## Objective
# Pipeline that:
# (i) establishes the empirical existence of post-dividend-change return drift <br>
# (ii) identifies the conditions under which this drift is strongest<br>
# (iii) constructs a machine learning model to predict dividend changes using earnings-related features<br>
# (iv) translates these predictions into a dollar-neutral long-short equity strategy with realistic performance evaluation

# %% [markdown]
# ## Data directly related to research strategy
# - Prices
# - Dividend payouts
# - Earnings-to-Dividend
# -

# %% [markdown]
# ## Additional information that could be useful
# - NLP (headline sentiment) - *build out sentiment score system, but keep it simple?*

# %% [markdown]
# ## ChatGPT Generated Checklist
# | Data block                    | What you need                                                                                       |                                        Why you need it |                                             Bloomberg likely? |
# | ----------------------------- | --------------------------------------------------------------------------------------------------- | -----------------------------------------------------: | ------------------------------------------------------------: |
# | **Universe**                  | S&P 1500 constituents, ideally historical membership                                                |                                Avoid survivorship bias |              **Yes**, but historical membership may need care |
# | **Dividend history**          | Declaration date, ex-date, record date, payment date, dividend per share, dividend type             |                                 Main target/event data |                                                       **Yes** |
# | **Earnings announcements**    | Announcement date, actual EPS, consensus EPS, EPS surprise, forecast dispersion                     |                Predict dividend changes after earnings |                                                       **Yes** |
# | **Daily prices**              | Adjusted close, open, close, volume, market cap                                                     |                         Event study, returns, backtest |                                                       **Yes** |
# | **Fundamentals**              | EPS, total assets, operating cash flow, FCF, debt, equity, current assets/liabilities, payout ratio |                   Features for dividend sustainability |                                                       **Yes** |
# | **Buyback / repurchase data** | Share repurchases, share issuances, net buyback yield, total payout yield                           | Required because buybacks may substitute for dividends |                 **Yes**, likely via cash flow statement items |
# | **Sector classification**     | GICS sector, industry group, industry                                                               |               Sector controls and conditional analysis |                                                       **Yes** |
# | **Macro data**                | VIX, 10Y yield, 2Y yield, Fed Funds rate, S&P 500 returns                                           |         Regime features and conditional drift analysis |                              **Yes**, but FRED is easier/free |
# | **Factor data**               | Fama-French 5 factors + momentum                                                                    |      Factor regression in final performance evaluation | **Not ideal from Bloomberg**; use Kenneth French data library |
#
#
# <br>
# Each row should look similar to this:
#
# | instrument_id  | earnings_date | next_dividend_declaration_date |          target_dividend_action | features available at earnings_date                                     |
# | -------------- | ------------: | -----------------------------: | ------------------------------: | ----------------------------------------------------------------------- |
# | AAPL US Equity |    2018-01-31 |                     2018-02-01 | unchanged / increase / decrease | EPS surprise, payout ratio, leverage, FCF coverage, momentum, VIX, etc. |
